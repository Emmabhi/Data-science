# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
y = pd.get_dummies(df['Churn'])

# %%
y = y.drop(columns='Yes')

# %%
x = df.drop('Churn',axis = 'columns')

# %%
x
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
y
# Out:
#       No
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
# ...   ..
# 7038   1
# 7039   1
# 7040   1
# 7041   0
# 7042   1
#
# [7043 rows x 1 columns]

# %%
x['Output'] = y

# %%
x
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df1_yes = x[x['Output'] == 0]
df1_no = x[x['Output'] == 1]

# %%
df1_no.shape,df1_yes.shape
# Out:
# ((5174, 21), (1869, 21))

# %%
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from sklearn.metrics import classification_report

# %%
def Ann(d1,d2):
    d1 = pd.concat([d1,d2],axis=0)
    X = d1.drop('Output',axis = 1)
    Y = d1['Output']
    x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.25,random_state = 0,stratify = Y)
    model = keras.Sequential([
        keras.layers.Dense(Y.shape[0],input_dim=Y.shape[0],activation='relu'),
        keras.layers.Dense(100,activation='relu'),
        keras.layers.Dense(50,activation='relu'),
        keras.layers.Dense(25,activation='relu'),
        keras.layers.Dense(5,activation='relu'),
        keras.layers.Dense(1,activation='sigmoid'),
    ])
    
    model.compile(
        loss = 'binary_crossentropy',
        optimizer = 'adam',
        metrics = ['accuracy']
    )
    
    model.fit(x_train,y_train,epochs = 200,batch_size = 10)
    model.evaluate(x_test,y_test)
    y_pred = model.predict(x_test)
    y_pred = np.round(y_pred)
    report = classification_report(y_test,y_pred)
    return y_pred,report

# %% [markdown]
# # 1 sample from majority

# %%
df1_no_sample = df1_no.sample(df1_yes.shape[0])

# %%
df1_no_sample.shape,df1_yes.shape
# Out:
# ((1869, 21), (1869, 21))

# %% [markdown]
# # 2 over sampling of minority

# %%
df1_yes_over = df1_yes.sample(df1_no.shape[0],replace=True)

# %%
df1_yes_over.shape
# Out:
# (5174, 21)

# %%
df1_no.shape
# Out:
# (5174, 21)

# %% [markdown]
# # 3 smote

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

# %%
smote = SMOTE()

# %%
x_yes = df1_yes.drop('Output',axis = 1)
y_yes = df1_yes['Output']

# %%
x_yes_over,y_yes_over = smote.fit_resample(x_yes,y_yes)

# %% [markdown]
# # 4 Random under sample

# %%
from imblearn.under_sampling import RandomUnderSampler

# %%
ru = RandomUnderSampler()

# %%
x_yes_under,y_yes_under = ru.fit_resample(x_yes,y_yes)

# %% [markdown]
# # 5 use sss for majority and divide into subgroups of shape minority and train with minority one and take maximum

# %%
# after splitting
from sklearn.ensemble import VotingClassifier # or votingregressor 

# classifier will return individual regressor will return average score
model =  VotingClassifier(estimators=[('dt', clf1), ('knn', clf2), ('svc', clf3)] # here you can use multiple models, 
                          voting # voting can be soft or hard,
                          weights=[2, 1, 2] # weights to models)

# %% [markdown]
# # 6 Focal loss
