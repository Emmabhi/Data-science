# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('abalone.csv')

# %%
df.head()
# Out:
#   Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings
# 0          0.1010         0.150     15
# 1          0.0485         0.070      7
# 2          0.1415         0.210      9
# 3          0.1140         0.155     10
# 4          0.0395         0.055      7

# %%
df.isnull().sum()
# Out:
# Gender            0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Gender, dtype: int64

# %%
encode = LabelEncoder()

# %%
l = encode.fit_transform(df.Gender)

# %%
df['gender'] = l

# %%
df.head()
# Out:
#   Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
#
#    Viscera weight  Shell weight  Rings  gender
# 0          0.1010         0.150     15       2
# 1          0.0485         0.070      7       2
# 2          0.1415         0.210      9       0
# 3          0.1140         0.155     10       2
# 4          0.0395         0.055      7       1

# %%
df.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
# gender         -0.036066 -0.038874 -0.042077     -0.021391       -0.001373
#
#                 Viscera weight  Shell weight     Rings    gender
# Length                0.903018      0.897706  0.556720 -0.036066
# Diameter              0.899724      0.905330  0.574660 -0.038874
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from matplotlib import pyplot as plt
plt.scatter(df['Gender'], df['Rings'])
plt.xlabel('Gender')
plt.ylabel('Rings')
plt.show()

# %%
x = df.iloc[:,1:8]

# %%
y = df['Rings']

# %%
x
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# ...      ...       ...     ...           ...             ...             ...
# 4172   0.565     0.450   0.165        0.8870          0.3700          0.2390
# 4173   0.590     0.440   0.135        0.9660          0.4390          0.2145
# 4174   0.600     0.475   0.205        1.1760          0.5255          0.2875
# 4175   0.625     0.485   0.150        1.0945          0.5310          0.2610
# 4176   0.710     0.555   0.195        1.9485          0.9455          0.3765
#
#       Shell weight
# 0           0.1500
# ...

# %%
features = (0.455,0.365,0.095,0.5140,0.2245,0.1010,0.1500)

# %%
l = np.zeros(4177)
m = l.reshape(4177,1)
for i in range(7):
    d = (x.iloc[:,i:i+1]-features[i])**2
    d = np.array(d)
    m = m + d
m = m**0.5

# %%
print(m)
# Out:
# [[0.        ]
#  [0.35925409]
#  [0.20756505]
#  ...
#  [0.79612578]
#  [0.72399137]
#  [1.6981406 ]]

# %%
df['distance'] = m

# %%
df
# Out:
#      Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0         M   0.455     0.365   0.095        0.5140          0.2245
# 1         M   0.350     0.265   0.090        0.2255          0.0995
# 2         F   0.530     0.420   0.135        0.6770          0.2565
# 3         M   0.440     0.365   0.125        0.5160          0.2155
# 4         I   0.330     0.255   0.080        0.2050          0.0895
# ...     ...     ...       ...     ...           ...             ...
# 4172      F   0.565     0.450   0.165        0.8870          0.3700
# 4173      M   0.590     0.440   0.135        0.9660          0.4390
# 4174      M   0.600     0.475   0.205        1.1760          0.5255
# 4175      F   0.625     0.485   0.150        1.0945          0.5310
# 4176      M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings  gender  distance
# 0             0.1010        0.1500     15       2  0.000000
# ...

# %%
df = df.sort_values('distance')

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns = ['index','gender'])
# Out:
#      Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0         M   0.455     0.365   0.095        0.5140          0.2245
# 1         I   0.465     0.370   0.100        0.5055          0.2340
# 2         F   0.450     0.355   0.105        0.5225          0.2370
# 3         I   0.465     0.360   0.105        0.4980          0.2140
# 4         M   0.460     0.350   0.120        0.5150          0.2240
# ...     ...     ...       ...     ...           ...             ...
# 4172      F   0.750     0.610   0.235        2.5085          1.2320
# 4173      M   0.780     0.600   0.210        2.5480          1.1945
# 4174      F   0.780     0.630   0.215        2.6570          1.4880
# 4175      M   0.730     0.595   0.230        2.8255          1.1465
# 4176      M   0.775     0.630   0.250        2.7795          1.3485
#
#       Viscera weight  Shell weight  Rings  distance
# 0             0.1010        0.1500     15  0.000000
# ...

# %%
df
# Out:
#       index Gender  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0         0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      3440      I   0.465     0.370   0.100        0.5055          0.2340
# 2        37      F   0.450     0.355   0.105        0.5225          0.2370
# 3       624      I   0.465     0.360   0.105        0.4980          0.2140
# 4       146      M   0.460     0.350   0.120        0.5150          0.2240
# ...     ...    ...     ...       ...     ...           ...             ...
# 4172   1427      F   0.750     0.610   0.235        2.5085          1.2320
# 4173   3715      M   0.780     0.600   0.210        2.5480          1.1945
# 4174   1209      F   0.780     0.630   0.215        2.6570          1.4880
# 4175    891      M   0.730     0.595   0.230        2.8255          1.1465
# 4176   1763      M   0.775     0.630   0.250        2.7795          1.3485
#
#       Viscera weight  Shell weight  Rings  gender  distance
# ...

# %%
df1 = df.head()

# %%
h = 0
lis = dict(df['distance'])
m = False
for i in range(len(lis)):
    if lis[i] == 0:
        m = True
        h = i
        break
    else:
        pass
    
if m == True:
    g = df.iloc[i:i+1,:]
    gy = dict(g['Rings'])
    val = gy.values()
    print(list(val))
    
else:
    print(int(df1['Rings'].mean()))
# Out:
# [15]
